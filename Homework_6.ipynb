# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvaro-Fdz-Glz/Neural_Networks_Pytorch/blob/master/Homework_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # Homework 6: Dense Neural Networks with Pytorch
#
# ------------------------------------------------------
# *Machine Learning, Master in Big Data Analytics, 2018-2019*
#
# *Pablo M. Olmos olmos@tsc.uc3m.es*
#
# ------------------------------------------------------
#
# In this homework you will deploy a simple Neural Network binary classifier for the Credit Default database from the [UCI repository](https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients). The goal is to predict the probability of a default credit payment of different purchases, according to features such as amount of the given credit, history of past payment, or payment delay for nine months.

# %% [markdown]
# Make sure you have reviewed the material of the [Pytorch Facebook Udacity course](https://github.com/udacity/deep-learning-v2-pytorch.git), particularly the assigments in the `intro_to_pytorch` folder.
#
# The homework is completely open. The following steps must be fullfilled:
#
# - Download the dataset.
# - Check out if there are categorical or nominal variables. If so, replace them by their [one-hot encoding representation](https://towardsdatascience.com/ml-intro-5-one-hot-encoding-cyclic-representations-normalization-6f6e2f4ec001). You can use the pandas method [get_dummies](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html). Split in train (60%), validation (20%), and test (20%) sets. Normalize real variables in both sets **2 points**.
# - Create a pytorch model class that defines a Neural Network with at two dense layers, non-linear activations at your choice and the appropiate final activation function for a binary classifier. Define the loss function, the batch size and the optimizer to be used. **3 points**.
# - Train the model using mini-batch stochastic gradiend descent. Plot the evolution of both train and validation error rate during training. **3 points**.
# - Define a new Neural Network model with four layers. Introduce Dropout as a regularization technique. Plot the evolution of both train and validation error rate during training **2 points**.
#
# **Note:** there are tons of parameters that should be selected by cross-validation (number of hidden units per layer, activation functions, mini-batch size, etc ...). Do not worry about this issue, just make your own choice and compare both models. The goal of this homework is that you learn how to use pytorch, not to really make fine-tunning of Neural Networks.

# %% [markdown]
# **Note-2:** Load the dataset with pandas, export to numpy and then to a pytorch tensor with the method `torch.from_numpy()`. E.g.
#
# `import torch`
#
# `X_train_torch = torch.from_numpy(X_train)`
#
# `y_train_torch = torch.from_numpy(y_train.astype(np.int64)`

# %% [markdown]
# **Note-3**: You can compare the performance achieved by the Neural Network with other methods in Table 1 of this [paper](https://www.sciencedirect.com/science/article/pii/S0957417407006719)

# %% [markdown]
# Check out if there are categorical or nominal variables. If so, replace them by their one-hot encoding representation. You can use the pandas method get_dummies. Split in train (60%), validation (20%), and test (20%) sets. Normalize real variables in both sets 2 points.

# %%
import pandas as pd

pd.read_excel
# https://stanford.edu/~shervine/blog/pytorch-how-to-generate-data-parallel
# Out:
# <function pandas.io.excel.read_excel>

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.

#https://drive.google.com/open?id=

# %%
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '15Li8uQEbtW6Do4yZf4QUCWsD2nuhUSAn'
downloaded = drive.CreateFile({'id': file_id})
#print('Downloaded content "{}"'.format(downloaded.GetContentString()))


downloaded.GetContentFile('Data.csv')  
df1 = pd.read_excel('Data.csv',header=1)
df1=df1.drop('ID',axis=1)
label=list(df1)[-1]

# %%
import numpy as np
import torch

arr=np.arange(df1.shape[0])
np.random.shuffle(arr)

partition={'train':list(arr[0:18000]),'validation':list(arr[18000:24000]),'test':list(arr[24000::])}
y=df1[label]

labels={k:torch.tensor(y[k],dtype=torch.float) for k in df1.index}


X=df1.drop(columns=label)
print(df1.shape)
X=pd.get_dummies(X,columns=["SEX","EDUCATION","MARRIAGE"])
len(labels)
# Out:
# (30000, 24)
# 30000

# %%
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

ssc=StandardScaler()
X.iloc[partition['train'],np.arange(20)] = ssc.fit_transform(X.iloc[partition['train'],np.arange(20)])
X.iloc[partition['validation'],np.arange(20)] = ssc.transform(X.iloc[partition['validation'],np.arange(20)])
X.iloc[partition['test'],np.arange(20)] = ssc.transform(X.iloc[partition['test'],np.arange(20)])

# %%
X_tensor=torch.tensor(np.array(X))
X_tensor=X_tensor.float()
y_tensor=torch.tensor(np.array(y))

y_tensor=y_tensor.float()

# %% [markdown]
# Create a pytorch model class that defines a Neural Network with at two dense layers, non-linear activations at your choice and the appropiate final activation function for a binary classifier. Define the loss function, the batch size and the optimizer to be used. 3 points.

# %%
import torch
from torch.utils import data

import torch
from torch.utils import data

class Dataset(data.Dataset):
  'Characterizes a dataset for PyTorch'
  def __init__(self, list_IDs, labels, dat):
        'Initialization'
        self.labels = labels
        self.list_IDs = list_IDs
        self.dat = dat

  def __len__(self):
        'Denotes the total number of samples'
        return len(self.list_IDs)

  def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        ID = self.list_IDs[index]

        # Load data and get label
        X = self.dat[ID] #torch.load('data/' + ID + '.pt')
        y = self.labels[ID]

        return X, y

# %%
params = {'batch_size': 100,'shuffle': True,'num_workers': 6}

training_set = Dataset(partition['train'],labels,dat=X_tensor)
training_generator = data.DataLoader(training_set,**params)

validation_set = Dataset(partition['validation'],labels,dat=X_tensor)
validation_generator = data.DataLoader(validation_set,**params)

test_set = Dataset(partition['test'],labels,dat=X_tensor)
test_generator = data.DataLoader(test_set,**params)

# %%
import torch
from torchvision import datasets, transforms
from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(33, 40)
        self.fc2 = nn.Linear(40, 1)

    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0],-1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.sigmoid(x)
        
        return x
      
model = Classifier()
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# Train the model using mini-batch stochastic gradiend descent. Plot the evolution of both train and validation error rate during training. 3 points.

# %%
# TODO: Train the network here
epochs = 300

train_losses, test_losses = [], []

for e in range(epochs):
  running_loss = 0
  for images, labels_to_train in training_generator:
      log_ps = model(images)
      loss = criterion(log_ps,labels_to_train)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      running_loss += loss.item()

  else:
      test_loss = 0
      accuracy = 0

      # Turn off gradients for validation, saves memory and computations
      with torch.no_grad():
          for images, labels_validation in validation_generator:
              log_ps = model(images)
              test_loss += criterion(log_ps, labels_validation)

  train_losses.append(running_loss/len(training_generator))
  test_losses.append(test_loss/len(validation_generator))
  
  model.train()
  
  print("Epoch: {}/{}.. ".format(e+1, epochs),
              "Training Loss: {:.3f}.. ".format(running_loss/len(training_generator)),
              "Validation Loss: {:.3f}.. ".format(test_loss/len(validation_generator)))
# Out:
# Epoch: 1/300..  Training Loss: 0.692..  Validation Loss: 0.689..
# Epoch: 2/300..  Training Loss: 0.688..  Validation Loss: 0.687..
# Epoch: 3/300..  Training Loss: 0.687..  Validation Loss: 0.687..
# Epoch: 4/300..  Training Loss: 0.686..  Validation Loss: 0.687..
# Epoch: 5/300..  Training Loss: 0.686..  Validation Loss: 0.686..
# Epoch: 6/300..  Training Loss: 0.686..  Validation Loss: 0.686..
# Epoch: 7/300..  Training Loss: 0.686..  Validation Loss: 0.686..
# Epoch: 8/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 9/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 10/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 11/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 12/300..  Training Loss: 0.685..  Validation Loss: 0.687..
# Epoch: 13/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 14/300..  Training Loss: 0.685..  Validation Loss: 0.687..
# Epoch: 15/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 16/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 17/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 18/300..  Training Loss: 0.685..  Validation Loss: 0.686..
# Epoch: 19/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 20/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 21/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 22/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 23/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 24/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 25/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 26/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 27/300..  Training Loss: 0.684..  Validation Loss: 0.686..
# Epoch: 28/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 29/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 30/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 31/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 32/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 33/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 34/300..  Training Loss: 0.684..  Validation Loss: 0.685..
# Epoch: 35/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 36/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 37/300..  Training Loss: 0.683..  Validation Loss: 0.687..
# Epoch: 38/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 39/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 40/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 41/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 42/300..  Training Loss: 0.683..  Validation Loss: 0.685..
# Epoch: 43/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 44/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 45/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 46/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 47/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 48/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 49/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 50/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 51/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 52/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 53/300..  Training Loss: 0.683..  Validation Loss: 0.684..
# Epoch: 54/300..  Training Loss: 0.682..  Validation Loss: 0.685..
# Epoch: 55/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 56/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 57/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 58/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 59/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 60/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 61/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 62/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 63/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 64/300..  Training Loss: 0.682..  Validation Loss: 0.683..
# Epoch: 65/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 66/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 67/300..  Training Loss: 0.682..  Validation Loss: 0.683..
# Epoch: 68/300..  Training Loss: 0.682..  Validation Loss: 0.684..
# Epoch: 69/300..  Training Loss: 0.682..  Validation Loss: 0.683..
# Epoch: 70/300..  Training Loss: 0.682..  Validation Loss: 0.683..
# Epoch: 71/300..  Training Loss: 0.682..  Validation Loss: 0.683..
# Epoch: 72/300..  Training Loss: 0.682..  Validation Loss: 0.683..
# Epoch: 73/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 74/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 75/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 76/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 77/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 78/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 79/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 80/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 81/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 82/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 83/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 84/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 85/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 86/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 87/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 88/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 89/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 90/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 91/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 92/300..  Training Loss: 0.681..  Validation Loss: 0.684..
# Epoch: 93/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 94/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 95/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 96/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 97/300..  Training Loss: 0.681..  Validation Loss: 0.683..
# Epoch: 98/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 99/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 100/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 101/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 102/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 103/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 104/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 105/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 106/300..  Training Loss: 0.680..  Validation Loss: 0.684..
# Epoch: 107/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 108/300..  Training Loss: 0.680..  Validation Loss: 0.684..
# Epoch: 109/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 110/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 111/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 112/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 113/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 114/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 115/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 116/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 117/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 118/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 119/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 120/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 121/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 122/300..  Training Loss: 0.680..  Validation Loss: 0.685..
# Epoch: 123/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 124/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 125/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 126/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 127/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 128/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 129/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 130/300..  Training Loss: 0.680..  Validation Loss: 0.683..
# Epoch: 131/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 132/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 133/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 134/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 135/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 136/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 137/300..  Training Loss: 0.679..  Validation Loss: 0.685..
# Epoch: 138/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 139/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 140/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 141/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 142/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 143/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 144/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 145/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 146/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 147/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 148/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 149/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 150/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 151/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 152/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 153/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 154/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 155/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 156/300..  Training Loss: 0.679..  Validation Loss: 0.683..
# Epoch: 157/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 158/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 159/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 160/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 161/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 162/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 163/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 164/300..  Training Loss: 0.679..  Validation Loss: 0.684..
# Epoch: 165/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 166/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 167/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 168/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 169/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 170/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 171/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 172/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 173/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 174/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 175/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 176/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 177/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 178/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 179/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 180/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 181/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 182/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 183/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 184/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 185/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 186/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 187/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 188/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 189/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 190/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 191/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 192/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 193/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 194/300..  Training Loss: 0.678..  Validation Loss: 0.684..
# Epoch: 195/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 196/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 197/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 198/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 199/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 200/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 201/300..  Training Loss: 0.677..  Validation Loss: 0.686..
# Epoch: 202/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 203/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 204/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 205/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 206/300..  Training Loss: 0.678..  Validation Loss: 0.685..
# Epoch: 207/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 208/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 209/300..  Training Loss: 0.677..  Validation Loss: 0.686..
# Epoch: 210/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 211/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 212/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 213/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 214/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 215/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 216/300..  Training Loss: 0.677..  Validation Loss: 0.686..
# Epoch: 217/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 218/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 219/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 220/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 221/300..  Training Loss: 0.677..  Validation Loss: 0.684..
# Epoch: 222/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 223/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 224/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 225/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 226/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 227/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 228/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 229/300..  Training Loss: 0.677..  Validation Loss: 0.687..
# Epoch: 230/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 231/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 232/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 233/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 234/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 235/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 236/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 237/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 238/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 239/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 240/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 241/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 242/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 243/300..  Training Loss: 0.677..  Validation Loss: 0.686..
# Epoch: 244/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 245/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 246/300..  Training Loss: 0.677..  Validation Loss: 0.685..
# Epoch: 247/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 248/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 249/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 250/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 251/300..  Training Loss: 0.677..  Validation Loss: 0.686..
# Epoch: 252/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 253/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 254/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 255/300..  Training Loss: 0.677..  Validation Loss: 0.686..
# Epoch: 256/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 257/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 258/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 259/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 260/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 261/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 262/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 263/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 264/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 265/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 266/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 267/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 268/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 269/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 270/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 271/300..  Training Loss: 0.676..  Validation Loss: 0.685..
# Epoch: 272/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 273/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 274/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 275/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 276/300..  Training Loss: 0.676..  Validation Loss: 0.687..
# Epoch: 277/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 278/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 279/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 280/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 281/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 282/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 283/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 284/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 285/300..  Training Loss: 0.675..  Validation Loss: 0.688..
# Epoch: 286/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 287/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 288/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 289/300..  Training Loss: 0.676..  Validation Loss: 0.686..
# Epoch: 290/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 291/300..  Training Loss: 0.675..  Validation Loss: 0.687..
# Epoch: 292/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 293/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 294/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 295/300..  Training Loss: 0.675..  Validation Loss: 0.687..
# Epoch: 296/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 297/300..  Training Loss: 0.675..  Validation Loss: 0.686..
# Epoch: 298/300..  Training Loss: 0.675..  Validation Loss: 0.688..
# Epoch: 299/300..  Training Loss: 0.675..  Validation Loss: 0.687..
# Epoch: 300/300..  Training Loss: 0.675..  Validation Loss: 0.687..

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
correct = 0
total = 1
with torch.no_grad():
    for data in test_generator:
        images, labels_test = data
        outputs = model.forward(images)
        #print(outputs>0.5)
        outputs=torch.tensor(outputs>0.5)
        temp=(labels_test==outputs.view(1,-1).float()).sum()
       
        #print(predicted)
        total += labels_test.size(0)
        correct += temp

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the test images: 81 %

# %% [markdown]
# Define a new Neural Network model with four layers. Introduce Dropout as a regularization technique. Plot the evolution of both train and validation error rate during training 2 points.

# %%
import torch.nn.functional as F

class Classifier_2(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(33, 100)
        self.fc2 = nn.Linear(100, 100)
        self.fc3 = nn.Linear(100, 40)
        self.fc4 = nn.Linear(40, 1)
        self.dropout = nn.Dropout(p=0.3)


    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0],-1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        x = self.dropout(F.relu(self.fc4(x)))
        x = F.sigmoid(x)
        
        return x

model_four_layers = Classifier_2()
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# TODO: Train the network here
epochs = 400

train_losses, test_losses = [], []

for e in range(epochs):
  model_four_layers.train()
  running_loss = 0
  for images, labels_to_train in training_generator:
      log_ps = model_four_layers(images)
      loss = criterion(log_ps,labels_to_train)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      #print(model_four_layers.forward(images))

      running_loss += loss.item()

  else:
      test_loss = 0
      accuracy = 0

      # Turn off gradients for validation, saves memory and computations
      with torch.no_grad():
          for images, labels_validation in validation_generator:
              log_ps = model_four_layers(images)
              test_loss += criterion(log_ps, labels_validation)

  train_losses.append(running_loss/len(training_generator))
  test_losses.append(test_loss/len(validation_generator))
  
   
  #print("Epoch: {}/{}.. ".format(e+1, epochs),
  #            "Training Loss: {:.3f}.. ".format(running_loss/len(training_generator)),
  #            "Validation Loss: {:.3f}.. ".format(test_loss/len(validation_generator)))
  
  
  correct = 0
  total = 0
  with torch.no_grad():
      for data in test_generator:
          images, labels_test = data
          outputs = model_four_layers.forward(images)
          #print(outputs>0.5)
          outputs=torch.tensor(outputs>0.5)
          temp=(labels_test==outputs.view(1,-1).float()).sum()

          _, predicted = torch.max(outputs.data, 1)

          #print(predicted)
          total += labels_test.size(0)
          correct += temp

  print('Accuracy of the network on the test images: %d %%' % (
      100 * correct / total))
# Out:
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 78 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 76 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %
# Accuracy of the network on the test images: 77 %

# %%
correct = 0
total = 1
with torch.no_grad():
    for data in test_generator:
        images, labels_test = data
        outputs = model_four_layers.forward(images)
        #print(outputs>0.5)
        outputs=torch.tensor(outputs>0.5)
        temp=(labels_test==outputs.view(1,-1).float()).sum()

        _, predicted = torch.max(outputs.data, 1)
        
        #print(predicted)
        total += labels_test.size(0)
        correct += temp

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the test images: 40 %

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)
